# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import pandas as pd
import os
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np
import matplotlib.pyplot as plt
application_df = pd.read_csv("charity_data.csv")
application_df.head()
# Out:
# 2023-01-29 23:27:38.468614: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
#preprocessing
application_df.drop(columns=['EIN', 'NAME'], inplace=True)
app_count = application_df['APPLICATION_TYPE'].value_counts()

replace_application = list(app_count[app_count < 500].index)

for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app,"Other")

class_count = application_df['CLASSIFICATION'].value_counts()
replace_class = list(class_count[class_count < 1800].index)
#Replace
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls,"Other")

application_cat = application_df.dtypes[application_df.dtypes == "object"].index.tolist()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(application_cat)
# Out:
# /Users/deepthivarun/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df,left_index=True, right_index=True)
application_df = application_df.drop(application_cat,1)
# Out:
# /var/folders/zs/_2x8z4sj32v_xq9f2kryblqr0000gn/T/ipykernel_9385/838529343.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   application_df = application_df.drop(application_cat,1)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df.IS_SUCCESSFUL.values
X = application_df.drop(columns=["IS_SUCCESSFUL"]).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)


# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the checkpoint path and filenames
os.makedirs("checkpoints_opt/",exist_ok=True)
checkpoint_path = "checkpoints_opt/weights.{epoch:02d}.hdf5"

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, 
                          input_dim=number_input_features, 
                          activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________
# 2023-01-29 23:31:32.617003: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq="epoch")

# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=50,callbacks=[cp_callback])

# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 769/804 [===========================>..] - ETA: 0s - loss: 0.5738 - accuracy: 0.7209
# Epoch 1: saving model to checkpoints_opt/weights.01.hdf5
# 804/804 [==============================] - 1s 947us/step - loss: 0.5723 - accuracy: 0.7217
# Epoch 2/50
# 776/804 [===========================>..] - ETA: 0s - loss: 0.5559 - accuracy: 0.7305
# Epoch 2: saving model to checkpoints_opt/weights.02.hdf5
# 804/804 [==============================] - 1s 985us/step - loss: 0.5553 - accuracy: 0.7306
# Epoch 3/50
# 759/804 [===========================>..] - ETA: 0s - loss: 0.5509 - accuracy: 0.7324
# Epoch 3: saving model to checkpoints_opt/weights.03.hdf5
# 804/804 [==============================] - 1s 878us/step - loss: 0.5518 - accuracy: 0.7323
# Epoch 4/50
# 752/804 [===========================>..] - ETA: 0s - loss: 0.5511 - accuracy: 0.7319
# Epoch 4: saving model to checkpoints_opt/weights.04.hdf5
# 804/804 [==============================] - 1s 952us/step - loss: 0.5506 - accuracy: 0.7322
# Epoch 5/50
# 767/804 [===========================>..] - ETA: 0s - loss: 0.5502 - accuracy: 0.7329
# Epoch 5: saving model to checkpoints_opt/weights.05.hdf5
# 804/804 [==============================] - 1s 943us/step - loss: 0.5496 - accuracy: 0.7337
# Epoch 6/50
# 775/804 [===========================>..] - ETA: 0s - loss: 0.5478 - accuracy: 0.7342
# Epoch 6: saving model to checkpoints_opt/weights.06.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5479 - accuracy: 0.7341
# Epoch 7/50
# 780/804 [============================>.] - ETA: 0s - loss: 0.5471 - accuracy: 0.7337
# Epoch 7: saving model to checkpoints_opt/weights.07.hdf5
# 804/804 [==============================] - 1s 986us/step - loss: 0.5471 - accuracy: 0.7333
# Epoch 8/50
# 790/804 [============================>.] - ETA: 0s - loss: 0.5475 - accuracy: 0.7335
# Epoch 8: saving model to checkpoints_opt/weights.08.hdf5
# 804/804 [==============================] - 1s 908us/step - loss: 0.5473 - accuracy: 0.7339
# Epoch 9/50
# 775/804 [===========================>..] - ETA: 0s - loss: 0.5455 - accuracy: 0.7352
# Epoch 9: saving model to checkpoints_opt/weights.09.hdf5
# 804/804 [==============================] - 1s 859us/step - loss: 0.5463 - accuracy: 0.7347
# Epoch 10/50
# 784/804 [============================>.] - ETA: 0s - loss: 0.5446 - accuracy: 0.7345
# Epoch 10: saving model to checkpoints_opt/weights.10.hdf5
# 804/804 [==============================] - 1s 850us/step - loss: 0.5448 - accuracy: 0.7345
# Epoch 11/50
# 802/804 [============================>.] - ETA: 0s - loss: 0.5449 - accuracy: 0.7361
# Epoch 11: saving model to checkpoints_opt/weights.11.hdf5
# 804/804 [==============================] - 1s 959us/step - loss: 0.5451 - accuracy: 0.7360
# Epoch 12/50
# 758/804 [===========================>..] - ETA: 0s - loss: 0.5455 - accuracy: 0.7357
# Epoch 12: saving model to checkpoints_opt/weights.12.hdf5
# 804/804 [==============================] - 1s 948us/step - loss: 0.5445 - accuracy: 0.7364
# Epoch 13/50
# 803/804 [============================>.] - ETA: 0s - loss: 0.5442 - accuracy: 0.7361
# Epoch 13: saving model to checkpoints_opt/weights.13.hdf5
# 804/804 [==============================] - 1s 959us/step - loss: 0.5441 - accuracy: 0.7362
# Epoch 14/50
# 766/804 [===========================>..] - ETA: 0s - loss: 0.5444 - accuracy: 0.7354
# Epoch 14: saving model to checkpoints_opt/weights.14.hdf5
# 804/804 [==============================] - 1s 938us/step - loss: 0.5433 - accuracy: 0.7365
# Epoch 15/50
# 773/804 [===========================>..] - ETA: 0s - loss: 0.5427 - accuracy: 0.7365
# Epoch 15: saving model to checkpoints_opt/weights.15.hdf5
# 804/804 [==============================] - 1s 999us/step - loss: 0.5437 - accuracy: 0.7358
# Epoch 16/50
# 800/804 [============================>.] - ETA: 0s - loss: 0.5435 - accuracy: 0.7354
# Epoch 16: saving model to checkpoints_opt/weights.16.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7355
# Epoch 17/50
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5433 - accuracy: 0.7358
# Epoch 17: saving model to checkpoints_opt/weights.17.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7361
# Epoch 18/50
# 755/804 [===========================>..] - ETA: 0s - loss: 0.5431 - accuracy: 0.7357
# Epoch 18: saving model to checkpoints_opt/weights.18.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7368
# Epoch 19/50
# 745/804 [==========================>...] - ETA: 0s - loss: 0.5439 - accuracy: 0.7336
# Epoch 19: saving model to checkpoints_opt/weights.19.hdf5
# 804/804 [==============================] - 1s 888us/step - loss: 0.5424 - accuracy: 0.7355
# Epoch 20/50
# 771/804 [===========================>..] - ETA: 0s - loss: 0.5416 - accuracy: 0.7376
# Epoch 20: saving model to checkpoints_opt/weights.20.hdf5
# 804/804 [==============================] - 1s 994us/step - loss: 0.5421 - accuracy: 0.7371
# Epoch 21/50
# 788/804 [============================>.] - ETA: 0s - loss: 0.5425 - accuracy: 0.7362
# Epoch 21: saving model to checkpoints_opt/weights.21.hdf5
# 804/804 [==============================] - 1s 977us/step - loss: 0.5416 - accuracy: 0.7369
# Epoch 22/50
# 794/804 [============================>.] - ETA: 0s - loss: 0.5415 - accuracy: 0.7377
# Epoch 22: saving model to checkpoints_opt/weights.22.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5417 - accuracy: 0.7374
# Epoch 23/50
# 765/804 [===========================>..] - ETA: 0s - loss: 0.5412 - accuracy: 0.7375
# Epoch 23: saving model to checkpoints_opt/weights.23.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7377
# Epoch 24/50
# 765/804 [===========================>..] - ETA: 0s - loss: 0.5401 - accuracy: 0.7383
# Epoch 24: saving model to checkpoints_opt/weights.24.hdf5
# 804/804 [==============================] - 1s 947us/step - loss: 0.5407 - accuracy: 0.7379
# Epoch 25/50
# 752/804 [===========================>..] - ETA: 0s - loss: 0.5410 - accuracy: 0.7376
# Epoch 25: saving model to checkpoints_opt/weights.25.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5406 - accuracy: 0.7382
# Epoch 26/50
# 791/804 [============================>.] - ETA: 0s - loss: 0.5412 - accuracy: 0.7374
# Epoch 26: saving model to checkpoints_opt/weights.26.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.7374
# Epoch 27/50
# 780/804 [============================>.] - ETA: 0s - loss: 0.5393 - accuracy: 0.7371
# Epoch 27: saving model to checkpoints_opt/weights.27.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7368
# Epoch 28/50
# 784/804 [============================>.] - ETA: 0s - loss: 0.5397 - accuracy: 0.7384
# Epoch 28: saving model to checkpoints_opt/weights.28.hdf5
# 804/804 [==============================] - 1s 981us/step - loss: 0.5395 - accuracy: 0.7383
# Epoch 29/50
# 792/804 [============================>.] - ETA: 0s - loss: 0.5391 - accuracy: 0.7385
# Epoch 29: saving model to checkpoints_opt/weights.29.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7385
# Epoch 30/50
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5397 - accuracy: 0.7386
# Epoch 30: saving model to checkpoints_opt/weights.30.hdf5
# 804/804 [==============================] - 1s 863us/step - loss: 0.5399 - accuracy: 0.7386
# Epoch 31/50
# 744/804 [==========================>...] - ETA: 0s - loss: 0.5378 - accuracy: 0.7400
# Epoch 31: saving model to checkpoints_opt/weights.31.hdf5
# 804/804 [==============================] - 1s 951us/step - loss: 0.5393 - accuracy: 0.7387
# Epoch 32/50
# 756/804 [===========================>..] - ETA: 0s - loss: 0.5400 - accuracy: 0.7385
# Epoch 32: saving model to checkpoints_opt/weights.32.hdf5
# 804/804 [==============================] - 1s 938us/step - loss: 0.5394 - accuracy: 0.7392
# Epoch 33/50
# 785/804 [============================>.] - ETA: 0s - loss: 0.5398 - accuracy: 0.7384
# Epoch 33: saving model to checkpoints_opt/weights.33.hdf5
# 804/804 [==============================] - 1s 912us/step - loss: 0.5390 - accuracy: 0.7390
# Epoch 34/50
# 791/804 [============================>.] - ETA: 0s - loss: 0.5390 - accuracy: 0.7384
# Epoch 34: saving model to checkpoints_opt/weights.34.hdf5
# 804/804 [==============================] - 1s 906us/step - loss: 0.5388 - accuracy: 0.7385
# Epoch 35/50
# 774/804 [===========================>..] - ETA: 0s - loss: 0.5388 - accuracy: 0.7398
# Epoch 35: saving model to checkpoints_opt/weights.35.hdf5
# 804/804 [==============================] - 1s 868us/step - loss: 0.5391 - accuracy: 0.7397
# Epoch 36/50
# 787/804 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.7399
# Epoch 36: saving model to checkpoints_opt/weights.36.hdf5
# 804/804 [==============================] - 1s 975us/step - loss: 0.5385 - accuracy: 0.7390
# Epoch 37/50
# 793/804 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.7403
# Epoch 37: saving model to checkpoints_opt/weights.37.hdf5
# 804/804 [==============================] - 1s 971us/step - loss: 0.5379 - accuracy: 0.7403
# Epoch 38/50
# 757/804 [===========================>..] - ETA: 0s - loss: 0.5390 - accuracy: 0.7397
# Epoch 38: saving model to checkpoints_opt/weights.38.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7404
# Epoch 39/50
# 756/804 [===========================>..] - ETA: 0s - loss: 0.5365 - accuracy: 0.7413
# Epoch 39: saving model to checkpoints_opt/weights.39.hdf5
# 804/804 [==============================] - 1s 944us/step - loss: 0.5377 - accuracy: 0.7397
# Epoch 40/50
# 772/804 [===========================>..] - ETA: 0s - loss: 0.5377 - accuracy: 0.7391
# Epoch 40: saving model to checkpoints_opt/weights.40.hdf5
# 804/804 [==============================] - 1s 927us/step - loss: 0.5375 - accuracy: 0.7394
# Epoch 41/50
# 781/804 [============================>.] - ETA: 0s - loss: 0.5383 - accuracy: 0.7390
# Epoch 41: saving model to checkpoints_opt/weights.41.hdf5
# 804/804 [==============================] - 1s 917us/step - loss: 0.5379 - accuracy: 0.7394
# Epoch 42/50
# 802/804 [============================>.] - ETA: 0s - loss: 0.5381 - accuracy: 0.7386
# Epoch 42: saving model to checkpoints_opt/weights.42.hdf5
# 804/804 [==============================] - 1s 895us/step - loss: 0.5379 - accuracy: 0.7387
# Epoch 43/50
# 789/804 [============================>.] - ETA: 0s - loss: 0.5380 - accuracy: 0.7394
# Epoch 43: saving model to checkpoints_opt/weights.43.hdf5
# 804/804 [==============================] - 1s 844us/step - loss: 0.5379 - accuracy: 0.7394
# Epoch 44/50
# 796/804 [============================>.] - ETA: 0s - loss: 0.5367 - accuracy: 0.7402
# Epoch 44: saving model to checkpoints_opt/weights.44.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7397
# Epoch 45/50
# 770/804 [===========================>..] - ETA: 0s - loss: 0.5370 - accuracy: 0.7400
# Epoch 45: saving model to checkpoints_opt/weights.45.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7394
# Epoch 46/50
# 750/804 [==========================>...] - ETA: 0s - loss: 0.5371 - accuracy: 0.7401
# Epoch 46: saving model to checkpoints_opt/weights.46.hdf5
# 804/804 [==============================] - 1s 952us/step - loss: 0.5374 - accuracy: 0.7400
# Epoch 47/50
# 780/804 [============================>.] - ETA: 0s - loss: 0.5370 - accuracy: 0.7395
# Epoch 47: saving model to checkpoints_opt/weights.47.hdf5
# 804/804 [==============================] - 1s 984us/step - loss: 0.5371 - accuracy: 0.7397
# Epoch 48/50
# 784/804 [============================>.] - ETA: 0s - loss: 0.5368 - accuracy: 0.7402
# Epoch 48: saving model to checkpoints_opt/weights.48.hdf5
# 804/804 [==============================] - 1s 914us/step - loss: 0.5372 - accuracy: 0.7399
# Epoch 49/50
# 790/804 [============================>.] - ETA: 0s - loss: 0.5369 - accuracy: 0.7406
# Epoch 49: saving model to checkpoints_opt/weights.49.hdf5
# 804/804 [==============================] - 1s 907us/step - loss: 0.5371 - accuracy: 0.7406
# Epoch 50/50
# 796/804 [============================>.] - ETA: 0s - loss: 0.5370 - accuracy: 0.7400
# Epoch 50: saving model to checkpoints_opt/weights.50.hdf5
# 804/804 [==============================] - 1s 964us/step - loss: 0.5369 - accuracy: 0.7402
# 268/268 - 0s - loss: 0.5593 - accuracy: 0.7231 - 292ms/epoch - 1ms/step
# Loss: 0.5592833757400513, Accuracy: 0.7231487035751343

# %%
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 60
hidden_nodes_layer2 = 40



nn_new = tf.keras.models.Sequential()

# First hidden layer
nn_new.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn_new.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn_new.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="linear"))

# Output layer
nn_new.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the model
nn_new.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_new.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 929us/step - loss: 0.5373 - accuracy: 0.7401
# Epoch 2/100
# 804/804 [==============================] - 1s 895us/step - loss: 0.5367 - accuracy: 0.7406
# Epoch 3/100
# 804/804 [==============================] - 1s 854us/step - loss: 0.5368 - accuracy: 0.7413
# Epoch 4/100
# 804/804 [==============================] - 1s 859us/step - loss: 0.5372 - accuracy: 0.7401
# Epoch 5/100
# 804/804 [==============================] - 1s 849us/step - loss: 0.5364 - accuracy: 0.7401
# Epoch 6/100
# 804/804 [==============================] - 1s 874us/step - loss: 0.5364 - accuracy: 0.7411
# Epoch 7/100
# 804/804 [==============================] - 1s 853us/step - loss: 0.5362 - accuracy: 0.7410
# Epoch 8/100
# 804/804 [==============================] - 1s 863us/step - loss: 0.5364 - accuracy: 0.7410
# Epoch 9/100
# 804/804 [==============================] - 1s 961us/step - loss: 0.5361 - accuracy: 0.7411
# Epoch 10/100
# 804/804 [==============================] - 1s 932us/step - loss: 0.5357 - accuracy: 0.7411
# Epoch 11/100
# 804/804 [==============================] - 1s 936us/step - loss: 0.5360 - accuracy: 0.7399
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7397
# Epoch 13/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7406
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7412
# Epoch 15/100
# 804/804 [==============================] - 1s 951us/step - loss: 0.5357 - accuracy: 0.7416
# Epoch 16/100
# 804/804 [==============================] - 1s 899us/step - loss: 0.5357 - accuracy: 0.7405
# Epoch 17/100
# 804/804 [==============================] - 1s 964us/step - loss: 0.5355 - accuracy: 0.7399
# Epoch 18/100
# 804/804 [==============================] - 1s 971us/step - loss: 0.5355 - accuracy: 0.7403
# Epoch 19/100
# 804/804 [==============================] - 1s 992us/step - loss: 0.5355 - accuracy: 0.7406
# Epoch 20/100
# 804/804 [==============================] - 1s 962us/step - loss: 0.5352 - accuracy: 0.7409
# Epoch 21/100
# 804/804 [==============================] - 1s 993us/step - loss: 0.5353 - accuracy: 0.7397
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7415
# Epoch 23/100
# 804/804 [==============================] - 1s 932us/step - loss: 0.5348 - accuracy: 0.7405
# Epoch 24/100
# 804/804 [==============================] - 1s 962us/step - loss: 0.5350 - accuracy: 0.7406
# Epoch 25/100
# 804/804 [==============================] - 1s 943us/step - loss: 0.5350 - accuracy: 0.7406
# Epoch 26/100
# 804/804 [==============================] - 1s 884us/step - loss: 0.5349 - accuracy: 0.7414
# Epoch 27/100
# 804/804 [==============================] - 1s 964us/step - loss: 0.5344 - accuracy: 0.7411
# Epoch 28/100
# 804/804 [==============================] - 1s 980us/step - loss: 0.5349 - accuracy: 0.7411
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7406
# Epoch 30/100
# 804/804 [==============================] - 1s 985us/step - loss: 0.5346 - accuracy: 0.7408
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7412
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7409
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7420
# Epoch 34/100
# 804/804 [==============================] - 1s 913us/step - loss: 0.5347 - accuracy: 0.7417
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7408
# Epoch 36/100
# 804/804 [==============================] - 1s 879us/step - loss: 0.5345 - accuracy: 0.7415
# Epoch 37/100
# 804/804 [==============================] - 1s 917us/step - loss: 0.5344 - accuracy: 0.7416
# Epoch 38/100
# 804/804 [==============================] - 1s 882us/step - loss: 0.5341 - accuracy: 0.7408
# Epoch 39/100
# 804/804 [==============================] - 1s 915us/step - loss: 0.5343 - accuracy: 0.7415
# Epoch 40/100
# 804/804 [==============================] - 1s 930us/step - loss: 0.5338 - accuracy: 0.7411
# Epoch 41/100
# 804/804 [==============================] - 1s 939us/step - loss: 0.5341 - accuracy: 0.7412
# Epoch 42/100
# 804/804 [==============================] - 1s 943us/step - loss: 0.5344 - accuracy: 0.7418
# Epoch 43/100
# 804/804 [==============================] - 1s 924us/step - loss: 0.5340 - accuracy: 0.7411
# Epoch 44/100
# 804/804 [==============================] - 1s 970us/step - loss: 0.5337 - accuracy: 0.7412
# Epoch 45/100
# 804/804 [==============================] - 1s 920us/step - loss: 0.5336 - accuracy: 0.7417
# Epoch 46/100
# 804/804 [==============================] - 1s 912us/step - loss: 0.5340 - accuracy: 0.7422
# Epoch 47/100
# 804/804 [==============================] - 1s 913us/step - loss: 0.5337 - accuracy: 0.7413
# Epoch 48/100
# 804/804 [==============================] - 1s 926us/step - loss: 0.5334 - accuracy: 0.7416
# Epoch 49/100
# 804/804 [==============================] - 1s 958us/step - loss: 0.5336 - accuracy: 0.7416
# Epoch 50/100
# 804/804 [==============================] - 1s 930us/step - loss: 0.5335 - accuracy: 0.7413
# Epoch 51/100
# 804/804 [==============================] - 1s 959us/step - loss: 0.5343 - accuracy: 0.7413
# Epoch 52/100
# 804/804 [==============================] - 1s 966us/step - loss: 0.5340 - accuracy: 0.7419
# Epoch 53/100
# 804/804 [==============================] - 1s 958us/step - loss: 0.5337 - accuracy: 0.7419
# Epoch 54/100
# 804/804 [==============================] - 1s 875us/step - loss: 0.5331 - accuracy: 0.7417
# Epoch 55/100
# 804/804 [==============================] - 1s 885us/step - loss: 0.5334 - accuracy: 0.7409
# Epoch 56/100
# 804/804 [==============================] - 1s 911us/step - loss: 0.5335 - accuracy: 0.7412
# Epoch 57/100
# 804/804 [==============================] - 1s 903us/step - loss: 0.5335 - accuracy: 0.7415
# Epoch 58/100
# 804/804 [==============================] - 1s 866us/step - loss: 0.5334 - accuracy: 0.7415
# Epoch 59/100
# 804/804 [==============================] - 1s 885us/step - loss: 0.5337 - accuracy: 0.7420
# Epoch 60/100
# 804/804 [==============================] - 1s 917us/step - loss: 0.5334 - accuracy: 0.7419
# Epoch 61/100
# 804/804 [==============================] - 1s 923us/step - loss: 0.5338 - accuracy: 0.7415
# Epoch 62/100
# 804/804 [==============================] - 1s 925us/step - loss: 0.5333 - accuracy: 0.7419
# Epoch 63/100
# 804/804 [==============================] - 1s 929us/step - loss: 0.5332 - accuracy: 0.7416
# Epoch 64/100
# 804/804 [==============================] - 1s 921us/step - loss: 0.5331 - accuracy: 0.7408
# Epoch 65/100
# 804/804 [==============================] - 1s 964us/step - loss: 0.5330 - accuracy: 0.7417
# Epoch 66/100
# 804/804 [==============================] - 1s 919us/step - loss: 0.5332 - accuracy: 0.7416
# Epoch 67/100
# 804/804 [==============================] - 1s 924us/step - loss: 0.5331 - accuracy: 0.7420
# Epoch 68/100
# 804/804 [==============================] - 1s 938us/step - loss: 0.5332 - accuracy: 0.7418
# Epoch 69/100
# 804/804 [==============================] - 1s 932us/step - loss: 0.5335 - accuracy: 0.7420
# Epoch 70/100
# 804/804 [==============================] - 1s 946us/step - loss: 0.5328 - accuracy: 0.7422
# Epoch 71/100
# 804/804 [==============================] - 1s 980us/step - loss: 0.5327 - accuracy: 0.7417
# Epoch 72/100
# 804/804 [==============================] - 1s 999us/step - loss: 0.5331 - accuracy: 0.7409
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7420
# Epoch 74/100
# 804/804 [==============================] - 1s 970us/step - loss: 0.5330 - accuracy: 0.7416
# Epoch 75/100
# 804/804 [==============================] - 1s 971us/step - loss: 0.5329 - accuracy: 0.7414
# Epoch 76/100
# 804/804 [==============================] - 1s 966us/step - loss: 0.5331 - accuracy: 0.7417
# Epoch 77/100
# 804/804 [==============================] - 1s 961us/step - loss: 0.5331 - accuracy: 0.7413
# Epoch 78/100
# 804/804 [==============================] - 1s 972us/step - loss: 0.5329 - accuracy: 0.7407
# Epoch 79/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.7415
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5327 - accuracy: 0.7418
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7419
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7420
# Epoch 83/100
# 804/804 [==============================] - 1s 941us/step - loss: 0.5324 - accuracy: 0.7413
# Epoch 84/100
# 804/804 [==============================] - 1s 960us/step - loss: 0.5329 - accuracy: 0.7419
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.7421
# Epoch 86/100
# 804/804 [==============================] - 1s 990us/step - loss: 0.5329 - accuracy: 0.7416
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7414
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7416
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7419
# Epoch 90/100
# 804/804 [==============================] - 1s 966us/step - loss: 0.5330 - accuracy: 0.7420
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7423
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5327 - accuracy: 0.7418
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7418
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5326 - accuracy: 0.7413
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7426
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7414
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7424
# Epoch 98/100
# 804/804 [==============================] - 1s 998us/step - loss: 0.5327 - accuracy: 0.7418
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7414
# Epoch 100/100
# 804/804 [==============================] - 1s 952us/step - loss: 0.5326 - accuracy: 0.7425
# 268/268 - 0s - loss: 0.7157 - accuracy: 0.5543 - 374ms/epoch - 1ms/step
# Loss: 0.7156580090522766, Accuracy: 0.5542857050895691

# %%
nn_new.save("AlphabetSoupCharity_Optimization.h5")
